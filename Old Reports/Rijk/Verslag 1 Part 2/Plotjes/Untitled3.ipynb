# %%
library("ggplot2")

# %%
plotname <- "part_2_withcoax"
txtfile <- paste(plotname, ".txt", sep="")

# %%
filename <- paste("~/Temp/", txtfile, sep="")

# %%
zl <- read.csv(file=filename, sep='\t')
zl$X <- NULL
names(zl)[names(zl)=="Ch1.mV."] <- "voltage [mV]"
names(zl)[names(zl)=="X.nS."] <- "time [nS]"
# Out:
#   File "<ipython-input-1-d2e43501675c>", line 2
#     zl$X <- NULL
#       ^
# SyntaxError: invalid syntax

# %%
ggplot(zl, aes(nS, mV)) + geom_line()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f51c02afc65e> in <module>()
# ----> 1 ggplot2(zl, aes(nS, mV)) + geom_line()
#
# NameError: name 'ggplot2' is not defined

# %%
zlfig <- ggplot(zl, aes(nS, mV)) + geom_line() +  scale_y_continuous(breaks=seq(-140,140,20), limits=c(-145,145))

# %%
zlfig
# Out:
# plot without title

# %%
ggsave(paste(plotname, ".pdf", sep=""))
# Out:
# Saving 7 x 7 in image

# %%
filename
# Out:
# [1] "~/Temp/open.txt"
